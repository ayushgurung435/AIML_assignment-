# %%
# %pip install seaborn

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, StratifiedKFold

# %%
dataframe = pd.read_csv("diabetes.csv")
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

X = dataframe.iloc[:,0:8]
Y = dataframe.iloc[:,8]

kfold = StratifiedKFold(n_splits=10,random_state= 2023,shuffle=True)

model = RandomForestClassifier(n_estimators= 200,random_state= 20,max_depth=None)
results = cross_val_score(model, X, Y, cv=kfold)
print(results)
print(results.mean())
# Out:
# [0.75324675 0.79220779 0.74025974 0.77922078 0.68831169 0.74025974
#  0.77922078 0.75324675 0.77631579 0.75      ]
# 0.755228981544771

# %% [markdown]
# ### Hyper parameter tuning GridSearchCV ###

# %%
from sklearn.model_selection import GridSearchCV
rf = RandomForestClassifier(random_state=42, n_jobs=-1)
params = {
    'max_depth': [2,3,5,None],
    'min_samples_leaf': [5,10,20],
    'n_estimators': [50,100,200,500],
    'max_features':["sqrt","log2",None],
    'criterion':["gini","entropy"]
}

grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 5,
                           n_jobs=-1, verbose=10, scoring="accuracy")
grid_search.fit(X, Y)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 1/5; 1/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.740 total time=   0.2s
# [CV 2/5; 1/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 2/5; 1/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.747 total time=   0.2s
# [CV 3/5; 1/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 3/5; 1/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.747 total time=   0.2s
# [CV 4/5; 1/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 4/5; 1/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.778 total time=   0.2s
# [CV 5/5; 1/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 5/5; 1/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.758 total time=   0.2s
# [CV 1/5; 2/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 1/5; 2/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.740 total time=   0.3s
# [CV 2/5; 2/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 2/5; 2/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.740 total time=   0.3s
# [CV 3/5; 2/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 3/5; 2/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.766 total time=   0.4s
# [CV 4/5; 2/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 4/5; 2/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.765 total time=   0.4s
# [CV 5/5; 2/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 5/5; 2/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.758 total time=   0.3s
# [CV 1/5; 3/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 1/5; 3/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.740 total time=   0.6s
# [CV 2/5; 3/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 2/5; 3/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.740 total time=   0.6s
# [CV 3/5; 3/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 3/5; 3/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.740 total time=   0.6s
# [CV 4/5; 3/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 4/5; 3/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.758 total time=   0.7s
# [CV 5/5; 3/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 5/5; 3/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.758 total time=   0.6s
# [CV 1/5; 4/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 1/5; 4/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.734 total time=   1.5s
# [CV 2/5; 4/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 2/5; 4/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.734 total time=   1.5s
# [CV 3/5; 4/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 3/5; 4/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.747 total time=   1.5s
# [CV 4/5; 4/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 4/5; 4/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.765 total time=   1.4s
# [CV 5/5; 4/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 5/5; 4/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.758 total time=   1.5s
# [CV 1/5; 5/288] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=50
# [CV 1/5; 5/288] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0
288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 1/5; 285/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.779 total time=   0.3s
# [CV 2/5; 285/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 2/5; 285/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.714 total time=   0.2s
# [CV 3/5; 285/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 3/5; 285/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.740 total time=   0.3s
# [CV 4/5; 285/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 4/5; 285/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.824 total time=   0.3s
# [CV 5/5; 285/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 5/5; 285/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.778 total time=   0.3s
# [CV 1/5; 286/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 1/5; 286/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.773 total time=   0.5s
# [CV 2/5; 286/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 2/5; 286/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.708 total time=   0.5s
# [CV 3/5; 286/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 3/5; 286/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.747 total time=   0.5s
# [CV 4/5; 286/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 4/5; 286/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.817 total time=   0.5s
# [CV 5/5; 286/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 5/5; 286/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.784 total time=   0.5s
# [CV 1/5; 287/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 1/5; 287/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.766 total time=   1.0s
# [CV 2/5; 287/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 2/5; 287/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.708 total time=   1.1s
# [CV 3/5; 287/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 3/5; 287/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.740 total time=   1.0s
# [CV 4/5; 287/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 4/5; 287/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.830 total time=   1.0s
# [CV 5/5; 287/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 5/5; 287/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.778 total time=   1.0s
# [CV 1/5; 288/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 1/5; 288/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.773 total time=   2.5s
# [CV 2/5; 288/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 2/5; 288/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.714 total time=   2.5s
# [CV 3/5; 288/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 3/5; 288/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.740 total time=   2.5s
# [CV 4/5; 288/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 4/5; 288/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.824 total time=   2.4s
# [CV 5/5; 288/288] START criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 5/5; 288/288] END criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.765 total time=   2.5s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, None],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [5, 10, 20],
#                          'n_estimators': [50, 100, 200, 500]},
#              scoring='accuracy', verbose=10)

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 100}
# 0.7826160767337238

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features=None,
#                        min_samples_leaf=5, n_jobs=-1, random_state=42)

# %%
model_best = RandomForestClassifier(criterion='entropy', max_features=None,
                                    min_samples_leaf=5, n_jobs=-1, random_state=42)
model.fit(X,Y)
model.feature_importances_
# Out:
# array([0.08291866, 0.26174215, 0.09088032, 0.06993518, 0.06936148,
#        0.16396211, 0.12629946, 0.13490065])

# %%
X = dataframe.iloc[:,0:8]
X.columns
# Out:
# Index(['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age'], dtype='object')

# %%
df = pd.DataFrame(model_best.feature_importances_, columns = ["Importance score"],index = X.columns)
df.sort_values(by = "Importance score", inplace = True, ascending = False,)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df = pd.DataFrame(model_best.feature_importances_, columns = ["Importance score"],index = X.columns)
#       2 df.sort_values(by = "Importance score", inplace = True, ascending = False,)
#
# File /lib/python3.12/site-packages/sklearn/ensemble/_forest.py:673, in BaseForest.feature_importances_(self)
#     652 @property
#     653 def feature_importances_(self):
#     654     """
#     655     The impurity-based feature importances.
#     656
#    (...)
#     671         array of zeros.
#     672     """
# --> 673     check_is_fitted(self)
#     675     all_importances = Parallel(n_jobs=self.n_jobs, prefer="threads")(
#     676         delayed(getattr)(tree, "feature_importances_")
#     677         for tree in self.estimators_
#     678         if tree.tree_.node_count > 1
#     679     )
#     681     if not all_importances:
#
# File /lib/python3.12/site-packages/sklearn/utils/validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
